# %% [markdown]
# Neural Style Network

# %%
"""! pip install tensorflow_hub
pip install opencv-contrib-python
pip install cv2
pip install opencv-python"""
# Out:
# '! pip install tensorflow_hub\npip install opencv-contrib-python\npip install cv2\npip install opencv-python'

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2
# Out:
# WARNING:tensorflow:From c:\Users\Samiksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')
# Out:
# WARNING:tensorflow:From c:\Users\Samiksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Samiksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\Samiksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\Samiksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

content_image = load_image("car1.jpeg")
style_image = load_image("hawk1.jpeg")

stylized_image = model(tf.constant(load_image("car1.jpeg")), tf.constant(load_image("hawk1.jpeg")))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()
